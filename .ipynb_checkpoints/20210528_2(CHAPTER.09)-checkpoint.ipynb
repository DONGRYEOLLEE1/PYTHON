# %%
import matplotlib.pyplot as plt
data = [10, 5, 2, 6, 20, 15]
plt.plot(data)
plt.show()

# %%
import numpy as np

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax1.hist(np.random.randn(100), bins=20, color='r', alpha=0.4)
ax2 = fig.add_subplot(2,2,2)
ax2.scatter(np.arange(30), np.arange(30)+ 3*np.random.randn(30), color='g', alpha=0.4)
ax3 = fig.add_subplot(2,2,3)
plt.plot(np.random.randn(50).cumsum(), 'k--')                # 'k--' => 점선을 그리기 위한 "스타일" 옵션
plt.show()

# %%
np.random.randn(30).cumsum()
# Out:
# array([-0.71159552, -1.7731756 , -0.23317564, -1.28993105,  0.45574483,
#         1.39341784,  1.21112281, -0.06320786, -0.62538294,  0.66853969,
#         1.0130538 ,  1.2156199 ,  0.77985761,  1.2405818 ,  0.64155713,
#         0.50129513,  1.41396265,  1.38781986,  0.67818243,  2.02255472,
#         1.70845365,  2.62815456,  3.88918433,  3.43126068,  3.2779494 ,
#         3.60785851,  4.22526614,  2.40003137,  1.33790687,  1.1757261 ])

# %%
# 색상, 마커, 선 스타일, 제목, 축이름, 눈금, 눈금 이름 설정, 라벨
data1 = [0.6348297 ,  0.33668372, -1.42509755, -0.75636556, -2.38113286,
       -2.54539369, -1.15851864, -2.19895727, -0.6538203 , -0.32358483,
       -0.71475953, -1.45365786, -2.30874354, -3.47201949, -3.37552546,
       -4.00488907, -4.1623595 , -5.37217833, -4.58753322, -3.16369808,
       -2.78475091, -2.92681129, -2.77438297, -2.37843248, -1.02175877,
       -0.61185583,  0.69782836,  1.27558234,  1.68397462,  1.73723268]
data2 = [-0.71159552, -1.7731756 , -0.23317564, -1.28993105,  0.45574483,
        1.39341784,  1.21112281, -0.06320786, -0.62538294,  0.66853969,
        1.0130538 ,  1.2156199 ,  0.77985761,  1.2405818 ,  0.64155713,
        0.50129513,  1.41396265,  1.38781986,  0.67818243,  2.02255472,
        1.70845365,  2.62815456,  3.88918433,  3.43126068,  3.2779494 ,
        3.60785851,  4.22526614,  2.40003137,  1.33790687,  1.1757261 ]

fig = plt.figure()                                   ##### 중요 STEP 1.
ax = fig.add_subplot(1,1,1)                          ##### 중요 STEP 2.
ax.plot(data1, 'ro', label = 'rand 1')               # '--'   => 각 포인트마다 선 잇기
ax.plot(data2, 'ko--', label = 'rand 2')             # 'ko--' => 마커가 포함된 그래프 스타일
ax.legend(loc='best')                                ### 범례 생성

ax.set_xticks([0, 10, 20, 30])
ax.set_xticklabels(['Start', 'Stage1', 'Stage2', 'Stage3'], rotation = 30, fontsize = 'small')
ax.set_xlabel("Progressive Stage")
ax.set_yticks([-5, 0, 5])
ax.set_ylabel("Value")
ax.set_title("Test Image")
# ax.text(9.4, -0.5, "first shock")

ax.annotate("First Shock", xy = (17.8, -5.4), xytext = (27, -4), arrowprops = dict(facecolor = 'blue'))
ax.annotate("Stabilization", xy = (13, 2), xytext = (6, 4), arrowprops = dict(facecolor = 'pink'))
rect = plt.Rectangle((10, 0), 10, 2, color = 'b', alpha = 0.2)
cir = plt.Circle((17.4, -5), 1.2, color = 'g', alpha = 0.2)
ax.add_patch(cir)
ax.add_patch(rect)

#### 마커를 사용하면 좀 더 명시적으로 표현할 수 있음.

plt.show()
ss

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
fig = plt.figure()
ax = fig.add_subplot(1,1,1)

rect = plt.Rectangle((0.2, 0.75), 0.65, 0.1, color = 'k', alpha = 0.3)
cir = plt.Circle((0.7, 0.2), 0.15, color = 'b', alpha = 0.3)
pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]], color = 'g', alpha = 0.5)


ax.text(0.38, 0.76, "This is a test sentence.")
ax.annotate("POLYGON", xy = (0.35, 0.4), xytext = (0.55, 0.4), arrowprops = dict(facecolor = 'blue'))
ax.add_patch(rect)
ax.add_patch(cir)
ax.add_patch(pgon)

plt.show()
