# %%
import pymysql as m
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rc("font",family="Malgun Gothic")
plt.rc("axes",unicode_minus=False)

# %%
con = m.connect(host='localhost', user='root', passwd='0720', charset='utf8')
cur = con.cursor()

# %%
q = "CREATE DATABASE PROJECT_PYTHON;"
cur.execute(q)
con.close()

# %%
df1 = pd.read_csv("nation_viitor.csv.csv")
df1
# Out:
#     Unnamed: 0               국가    방문자 수
# 0            0            China  6236504
# 1            1            Japan  3695581
# 2            2           Taiwan  1424629
# 3            3              USA  1170719
# 4            4        Hong Kong   783159
# 5            5         Thailand   644523
# 6            6          Vietnam   624921
# 7            7      Phillipines   560570
# 8            8         Malaysia   455722
# 9            9           Russia   400628
# 10          10        Indonesia   319442
# 11          11        Singapore   263056
# 12          12           Canada   231090
# 13          13  Overseas Korean   211216
# 14          14       Austrailia   194998
# 15          15            India   160252
# 16          16               UK   159830
# 17          17          Germany   135174
# 18          18         Mongolia   133611
# 19          19           France   123393
# 20          20       Uzbekistan   102088
# 21          21          Myanmar    86977
# 22          22      Asia others    84892
# 23          23       Kazakhstan    61077
# 24          24            Macao    58329
# 25          25    Africa others    54320
# 26          26            Italy    54245
# 27          27    Europe others    52069
# 28          28         Cambodia    50289
# 29          29   America others    47597
# 30          30      New Zealand    44792
# 31          31       Netherland    44743
# 32          32             *GCC    38103
# 33          33           Turkey    35553
# 34          34           Mexico    34580
# 35          35            Spain    33570
# 36          36          Ukraine    31986
# 37          37           Brazil    27120
# 38          38           Poland    27082
# 39          39           Sweden    21429
# 40          40        Sri Lanka    21427
# 41          41       Bangladesh    20824
# 42          42            Swiss    19313
# 43          43           Israel    18346
# 44          44         Pakistan    16313
# 45          45          Belgium    16029
# 46          46          Finland    15756
# 47          47     South Africa    15679
# 48          48          Denmark    14899
# 49          49          Romania    14363
# 50          50          Austria    14092
# 51          51           Norway    12886
# 52          52         Portugal    12531
# 53          53          Ireland    11519
# 54          54           Greece    11317
# 55          55         Bulgaria     7228
# 56          56          Croatia     6821
# 57          57   Oceania others     6168
# 58          58             Iran     4677
# 59          59        Stateless      727

# %%
df1_sample = df1.drop(['Unnamed: 0'], axis=1)
df1_sample
# Out:
#                  국가    방문자 수
# 0             China  6236504
# 1             Japan  3695581
# 2            Taiwan  1424629
# 3               USA  1170719
# 4         Hong Kong   783159
# 5          Thailand   644523
# 6           Vietnam   624921
# 7       Phillipines   560570
# 8          Malaysia   455722
# 9            Russia   400628
# 10        Indonesia   319442
# 11        Singapore   263056
# 12           Canada   231090
# 13  Overseas Korean   211216
# 14       Austrailia   194998
# 15            India   160252
# 16               UK   159830
# 17          Germany   135174
# 18         Mongolia   133611
# 19           France   123393
# 20       Uzbekistan   102088
# 21          Myanmar    86977
# 22      Asia others    84892
# 23       Kazakhstan    61077
# 24            Macao    58329
# 25    Africa others    54320
# 26            Italy    54245
# 27    Europe others    52069
# 28         Cambodia    50289
# 29   America others    47597
# 30      New Zealand    44792
# 31       Netherland    44743
# 32             *GCC    38103
# 33           Turkey    35553
# 34           Mexico    34580
# 35            Spain    33570
# 36          Ukraine    31986
# 37           Brazil    27120
# 38           Poland    27082
# 39           Sweden    21429
# 40        Sri Lanka    21427
# 41       Bangladesh    20824
# 42            Swiss    19313
# 43           Israel    18346
# 44         Pakistan    16313
# 45          Belgium    16029
# 46          Finland    15756
# 47     South Africa    15679
# 48          Denmark    14899
# 49          Romania    14363
# 50          Austria    14092
# 51           Norway    12886
# 52         Portugal    12531
# 53          Ireland    11519
# 54           Greece    11317
# 55         Bulgaria     7228
# 56          Croatia     6821
# 57   Oceania others     6168
# 58             Iran     4677
# 59        Stateless      727

# %%
df1_top5 = df1_sample.head()
df1_top5
# Out:
#           국가    방문자 수
# 0      China  6236504
# 1      Japan  3695581
# 2     Taiwan  1424629
# 3        USA  1170719
# 4  Hong Kong   783159

# %%
### 국가 별 방문자 수
sns.barplot(x="국가", y="방문자 수", data=df1_top5, log = True)
plt.xlabel('국가')
plt.ylabel('방문자 수')
plt.show()

# %%
df2 = pd.read_csv("TOP5_nation_purpose_ratio.csv.csv")
df2
# Out:
#    Unnamed: 0         국가       관광      사업      공무      유학
# 0           0     Taiwan  98.2479  0.0810  0.0155  0.3974
# 1           1  Hong Kong  97.8488  0.0977  0.0066  0.4196
# 2           2      Japan  97.0299  0.7629  0.0613  0.4420
# 3           3      China  80.5216  0.7170  0.0790  4.3149
# 4           4        USA  75.6001  0.4654  3.5476  0.5463

# %%
df2_sample = df2.drop(['Unnamed: 0'], axis=1)
df2_sample
# Out:
#           국가       관광      사업      공무      유학
# 0     Taiwan  98.2479  0.0810  0.0155  0.3974
# 1  Hong Kong  97.8488  0.0977  0.0066  0.4196
# 2      Japan  97.0299  0.7629  0.0613  0.4420
# 3      China  80.5216  0.7170  0.0790  4.3149
# 4        USA  75.6001  0.4654  3.5476  0.5463

# %%
df2_sample.plot.bar()
# Out:
# <AxesSubplot:>

# %%
###
df3 = pd.read_csv("5.business_TOP5.csv.csv")
df3
# Out:
#    Unnamed: 0             국가    사업 비율
# 0           0          China  22.6964
# 1           1          India  19.0170
# 2           2          Japan  14.3104
# 3           3        Vietnam   7.2481
# 4           4  Africa others   5.3726

# %%
df3_sample = df3.drop(['Unnamed: 0'], axis=1)
df3_sample
# Out:
#               국가    사업 비율
# 0          China  22.6964
# 1          India  19.0170
# 2          Japan  14.3104
# 3        Vietnam   7.2481
# 4  Africa others   5.3726

# %%
sum_etc = 100.0-float(df3_sample["사업 비율"].sum())
sum_etc
# Out:
# 31.355499999999992

# %%
df3['사업 비율'].sum()
# Out:
# 68.64450000000001

# %%
data ={"국가": "Others", "사업 비율":sum_etc}
df3_a = df3_sample.append(data,  ignore_index=True)
df3_a
# Out:
#               국가    사업 비율
# 0          China  22.6964
# 1          India  19.0170
# 2          Japan  14.3104
# 3        Vietnam   7.2481
# 4  Africa others   5.3726
# 5         Others  31.3555

# %%
plt.pie(df3_a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-9c9d1f60211c> in <module>
# ----> 1 plt.pie(df3_a)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    2825         textprops=None, center=(0, 0), frame=False,
#    2826         rotatelabels=False, *, normalize=None, data=None):
# -> 2827     return gca().pie(
#    2828         x, explode=explode, labels=labels, colors=colors,
#    2829         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize)
#    2993         # The use of float32 is "historical", but can't be changed without
#    2994         # regenerating the test baselines.
# -> 2995         x = np.asarray(x, np.float32)
#    2996         if x.ndim > 1:
#    2997             raise ValueError("x must be 1D")
#
# ~\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __array__(self, dtype)
#    1897
#    1898     def __array__(self, dtype=None) -> np.ndarray:
# -> 1899         return np.asarray(self._values, dtype=dtype)
#    1900
#    1901     def __array_wrap__(
#
# ~\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ValueError: could not convert string to float: 'China'
