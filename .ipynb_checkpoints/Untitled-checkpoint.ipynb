# %%
pip install geopandas
# Out:
# ...
#
# ...

# %%
import pandas as pd
import geopandas as gpd
# Out:
# '0.9.0'

# %%
df1 = pd.read_csv('Data/Project Data/1.광양시_공동주택_분리수거장현황.csv')
df1
# Out:
#    complex_nm             address         lon        lat
# 0    칠성주공1,2      광양시 광양읍 호북길 25   127.583121  34.982555
# 1       칠성주공3     광양시 광양읍 호북길 25   127.583121  34.982555
# 2          목성     광양시 광양읍 신재로 82   127.591379  34.978283
# 3          부영    광양시 광양읍 인서4길 20   127.584172  34.967477
# 4        오성타워  광양시 광양읍 대림오성로 139   127.576791  34.965288
# ..        ...                 ...         ...        ...
# 90      백합아파트          광양시 금호로 41  127.723044  34.933698
# 91       매화연립          광양시 희망길 39  127.720397  34.936325
# 92      사랑아파트          광양시 금호로 73  127.717120  34.934343
# 93      초원아파트        광양시 폭포사랑길 90  127.734357  34.938907
# 94      송죽아파트         광양시 금호로 135  127.718450  34.939268
#
# [95 rows x 4 columns]

# %%
df2 = pd.read_csv('Data/Project Data/2.광양시_재활용품분리수거_장려금지급내역.csv')
df2
# Out:
#           date emd_nm    complex_nm road_nm bldg_no      glass     pet  \
# 0     20180130    광양읍     칠성3단지 아파트     호북길     '25        0.0   28800
# 1     20180130    광양읍         부영아파트    인서4길     '19    11900.0    9600
# 2     20180226    광양읍     칠성3단지 아파트     호북길     '25        0.0   20400
# 3     20180226    금호동     광양제철주택관리소     희망길  '12-14  1018500.0  336400
# 4     20180226    광영동     그린파크관리사무소     가야로    '371    11200.0    4800
# ...        ...    ...           ...     ...     ...        ...     ...
# 1067  20210600    금호동     광양제철주택관리소     희망길  '12-14        0.0       0
# 1068  20210600    태인동       태인부영아파트     태인길      '1     6300.0     240
# 1069  20210600    태인동       선미태인하이츠    담안2길  '36-10    10500.0     960
# 1070  20210600    광양읍  송보7차아파트관리사무소     와룡길     '33        0.0       0
# 1071  20210600    광영동    브라운스톤가야아파트     가야로    '345    13300.0    1920
#
#       plastic   lamp   vinyl  battery  carton  smallappliance  hp  subsidy
# ...

# %%
df3 = pd.read_csv('Data/Project Data/3.광양시_금호동_집적장별_재할용품통계.csv')
df3
# Out:
#        apt_nm  can  plastic  glass  paper  scrapmetal
# 0    동백아파트 1동  0.3      1.5    0.3    0.0         0.3
# 1    동백아파트 4동  0.3      1.4    0.2    0.0         0.2
# 2    동백아파트 8동  3.6     16.5    2.3    0.4         2.7
# 3   동백아파트 14동  0.5      2.5    0.3    0.1         0.4
# 4     목련빌라 1동  3.6     16.4    2.3    0.4         2.7
# 5    목련빌라 11동  0.7      3.3    0.5    0.1         0.5
# 6    목련빌라 26동  3.5     15.7    2.2    0.3         2.6
# 7    목련빌라 33동  3.4     15.8    2.1    0.3         2.5
# 8    목련빌라 35동  0.5      2.1    0.3    0.1         0.3
# 9    장미아파트 2동  0.5      2.3    0.3    0.1         0.4
# 10   장미아파트 7동  0.4      1.8    0.3    0.0         0.3
# 11  장미아파트 14동  4.1     18.6    2.6    0.4         3.1
# 12  장미아파트 16동  0.7      3.1    0.4    0.1         0.5
# 13  장미아파트 21동  0.7      3.0    0.4    0.1         0.5
# 14  장미아파트 25동  0.4      1.6    0.2    0.0         0.3
# 15    장미연립 8동  1.1      4.9    0.7    0.1         0.8
# ...

# %%
df = gpd.read_file('Data/Project Data/6.광양시_법정경계(읍면동).geojson')
df
# Out:
# ---------------------------------------------------------------------------
# CRSError                                  Traceback (most recent call last)
# <ipython-input-3-4a9d09c26dbf> in <module>
# ----> 1 df = gpd.read_file('Data/Project Data/6.광양시_법정경계(읍면동).geojson')
#       2 df
#
# ~\anaconda3\lib\site-packages\geopandas\io\file.py in _read_file(filename, bbox, mask, rows, **kwargs)
#     201                 )
#     202
# --> 203             return GeoDataFrame.from_features(
#     204                 f_filt, crs=crs, columns=columns + ["geometry"]
#     205             )
#
# ~\anaconda3\lib\site-packages\geopandas\geodataframe.py in from_features(cls, features, crs, columns)
#     585             row.update(feature["properties"])
#     586             rows.append(row)
# --> 587         return GeoDataFrame(rows, columns=columns, crs=crs)
#     588
#     589     @classmethod
#
# ...
